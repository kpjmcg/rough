# %%
#| export 
import numpy as np
import imutils
import cv2 as cv
from matplotlib import pyplot as plt

from nbdev.showdoc import *
from rough.data import *
from rough.profile import *
from rough.areal import *

# %% [markdown]
# This notebook contains tests and comparisons between Rough and the Internet-based Surface Metrology Algorithm Testing System, published by NIST.
# https://physics.nist.gov/VSC/jsp/index.jsp

# %%
file = 'SMAT/Data3D_1/SG_1-1.txt'
image = np.loadtxt(file)

# %%
plt.imshow(image)
plt.show()

# %%
Sa(image)
# Out:
# 0.7972492402496817

# %%
Sms(image)
# Out:
# 1.0000000552480837

# %%
Sku(image)
# Out:
# 0.019626105861821674

# %%
Ssk(image)
# Out:
# 0.001342579063490285

# %%
Sp(image)
# Out:
# 4.479235945468537

# %%
Sv(image)
# Out:
# 4.243975629331464

# %%
Sz(image)
# Out:
# 8.7232115748
