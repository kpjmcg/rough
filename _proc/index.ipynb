# %% [raw]
# ---
# description: A simple package for calculating roughness parameters from numpy arrays
#   and rasters.
# output-file: index.html
# title: Rough
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install rough
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Calculating the [`Ra`](https://kpjmcg.github.io/rough/profile.html#ra) on a simple `profile`:

# %%
line = [1,2,3,4,5,6,7]
profile.Ra(line, axis = 0)
# Out:
# 1.7142857142857142

# %% [markdown]
# Or the [`Rms`](https://kpjmcg.github.io/rough/profile.html#rms)

# %%
profile.Rms(line, axis = 0)
# Out:
# 2.0
